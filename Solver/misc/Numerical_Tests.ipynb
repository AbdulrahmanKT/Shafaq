# %%
import SBP as sb
import numpy as np 
import matplotlib.pyplot as plt 
import scipy as sp 
np.set_printoptions(linewidth=np.inf)
from numpy.polynomial.legendre import legvander

# %%
# This function is for creating a triangular initial condition
def triangle(x):
    """
    Triangular (hat) function on [-1,1]:
      triangle(x) = 1 - |x|   for x in [-1,1],
                    0         otherwise.
    Accepts scalar or array x.
    """
    x = np.asarray(x)
    # compute 1 - |x|, then zero out anything outside [-1,1]
    u = 1 - np.abs(x)
    u = np.where((x < -1) | (x > 1), 0.0, u)
    return u

# This function is for converting from nodal to modal represntation of the solution vecotr
def nodal_to_modal(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    return a

# This function takes in a lower order solution and kills the highest frequency 
def modal_frequency_reduction(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    
    # 4) Killing the highest frequency term
    a[-1] = 0
    
    # 5) Return Modal to Nodal 
    a = V.dot(a)
    return a

# This function calculates the energy of the highest mode in a modal representation of a solution
def fractional_energy_highest_mode(a):
    """
    Compute the fraction of total L²‐energy contained in the highest Legendre mode.
    
    Parameters
    ----------
    a : array_like, shape (n+1,)
        Modal coefficients [a₀, a₁, …, aₙ] of a polynomial of degree n.
    
    Returns
    -------
    float
        Fractional energy in mode n:
          Eₙ / Σ_{i=0}ⁿ Eᵢ,
        where Eᵢ = aᵢ²·(2/(2i+1)).
    """
    a = np.asarray(a)
    n = a.size - 1
    i = np.arange(a.size)
    # energy in each mode: E[i] = a[i]**2 * (2/(2*i+1))
    E = a**2 * (2/(2*i + 1))
    return E[n] / E.sum()

# %%
############
# Sandro's Projection-Interpolation
############

n = 7 
k = 6
x7 , w7 = sb.lgl(n)
x6 , w6 = sb.lgl(k)

P6 = np.linalg.inv(sb.sbp_p(k))
P7 = sb.sbp_p(n)

##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

u7 = np.where(x7 < 0, 0.0, 1.0)


u6 = P6@(L6.T.dot(P7@u7))
##############################################


##############################################
u6_t = u7.T@np.array([sb.lagrange(k,x7[i]) for i in range(n+1)])
u7_6t2 = L6.dot(u6_t)

u7_6t1 = L6.dot(u6)
##############################################




fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x7,np.zeros_like(x7), "o",label="$x_7$")
ax.plot(x6,np.zeros_like(x6), "x",label="$x_6$")
ax.plot(x7,u7,label="P7 Solution")
#ax.plot(x6,u6,label="P6 Solution - Naive")
#ax.plot(x6,u6_t,label="P6 Solution - Minimum L2")
#ax.plot(x7,u7_6t2, label="P7 from P6 (Naive-Approach)")
ax.plot(x7,u7_6t1,label="P7 from P6 (L2 - Minimum)")
ax.legend()
ax.grid()
ax.set_title("Projecting P7 Jump onto a P6 Solution")
plt.show()

# %%
############
# Sandro's Projection-Interpolation
############
xf = np.linspace(-1, 1, 500)
n = 7 
k = 6
x7 , w7 = sb.lgl(n)
x6 , w6 = sb.lgl(k)

P6 = np.linalg.inv(sb.sbp_p(k))
P7 = sb.sbp_p(n)

##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

u7 = np.where(x7 < 0, 0.0, 1.0)


u6 = P6@(L6.T.dot(P7@u7))
##############################################


##############################################
u6_t = u7.T@np.array([sb.lagrange(k,x7[i]) for i in range(n+1)])
u7_6t2 = L6.dot(u6_t)

u7_6t1 = L6.dot(u6)
##############################################

#########################################################
# Visualizing the Lagrange Interpolation 
xf = np.linspace(-1, 1, 500)
Mn = np.vstack([ sb.lagrange(n, xi) for xi in xf ])   # shape (500×n)
Mk = np.vstack([ sb.lagrange(k, xi) for xi in xf ])   # shape (500×k or (n-1))


#########################################################


fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x7,np.zeros_like(x7), "o",label="$x_7$")
ax.plot(x6,np.zeros_like(x6), "x",label="$x_6$")
ax.plot(x7,u7,label="P7 Solution")
#ax.plot(x6,u6,label="P6 Solution - Naive")
#ax.plot(x6,u6_t,label="P6 Solution - Minimum L2")
#ax.plot(x7,u7_6t2, label="P7 from P6 (Naive-Approach)")
ax.plot(x7,u7_6t1,label="P7 from P6 (L2 - Minimum)")
ax.legend()
ax.grid()
ax.set_title("Projecting P7 Jump onto a P6 Solution")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# 1) Choose degree
n = 7

# 2) Get the LGL nodes (and weights, though weights aren’t needed here)
x7, _ = sb.lgl(n)        # shape = (8,)

# 3) Sample the step: 0 for x<0, 1 for x>=0
u7 = np.where(x7 < 0, 0.0, 1.0)   # length-8

# 4) Build the collocation‐to‐fine‐grid matrix
#    Let xf be a fine set of points in [-1,1]:
xf = np.linspace(-1, 1, 500)
#    M[j,i] = ℓᵢ⁽⁷⁾(xf[j])
M = np.vstack([ sb.lagrange(n, xi) for xi in xf ])   # shape (500×8)

# 5) Evaluate the P₇‐polynomial at those fine points
u_fine = M.dot(u7)       # shape = (500,)

# 6) Plot
plt.figure(figsize=(8,4))
plt.plot(xf,   u_fine,  '-', label='P₇ interpolant')
plt.scatter(x7, u7,     c='C1', marker='o', label='LGL nodes')
plt.axvline(0, color='k', linestyle='--', linewidth=0.5)
plt.ylim(-0.1, 1.1)
plt.xlabel('ξ')
plt.ylabel('u(ξ)')
plt.title('Step function (0 for ξ<0, 1 for ξ≥0) interpolated on P₇')
plt.legend()
plt.grid(True)
plt.show()

# %%
#######
# Vmonde Approach
#######

n = 7 
k = 6
x7 , w7 = sb.lgl(n)
x6 , w6 = sb.lgl(k)


##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

u7 = np.ones(n+1)
u7[0:3] = 0
u7_m = modal_frequency_reduction(u7, x7, w7)
##############################################




fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x7,np.zeros_like(x7), "o",label="$x_7$")
ax.plot(x6,np.zeros_like(x6), "x",label="$x_6$")
ax.plot(x7,u7,label="P7 Solution")
#ax.plot(x6,u6,label="P6 Solution - Naive")
#ax.plot(x6,u6_t,label="P6 Solution - Minimum L2")
#ax.plot(x7,u7_6t2, label="P7 from P6 (Naive-Approach)")
ax.plot(x7,u7_m,label="P7 from Modal Reduction")
ax.legend()
ax.grid()
ax.set_title("Projecting P7 Jump onto a P6 Solution")
plt.show()

# %%
n = 8 
k = n-1
x7 , w7 = sb.lgl(n)
x6 , w6 = sb.lgl(k)


##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

u7 = triangle(x7)

P6 = np.linalg.inv(sb.sbp_p(k))
P7 = sb.sbp_p(n)

u6 = P6@(L6.T.dot(P7@u7))
##############################################


##############################################
u6_t = u7.T@np.array([sb.lagrange(k,x7[i]) for i in range(n+1)])
u7_6t2 = L6.dot(u6_t)

u7_6t1 = L6.dot(u6)
##############################################




fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x7,np.zeros_like(x7), "o",label="$x_7$")
ax.plot(x6,np.zeros_like(x6), "x",label="$x_6$")
ax.plot(x7,u7,label="P7 Solution")
#ax.plot(x6,u6,label="P6 Solution - Naive")
ax.plot(x6,u6_t,label="P6 Solution - Minimum L2")
#ax.plot(x7,u7_6t2, label="P7 from P6 (Naive-Approach)")
ax.plot(x7,u7_6t1,"x",label="P7 from P6 (L2 - Minimum)")
ax.legend()
ax.grid()
ax.set_title("Projecting P7 Jump onto a P6 Solution")
plt.show()

# %%
#######
# Vmonde Approach
#######

n = 7 
k = 6
x7 , w7 = sb.lgl(n)
x6 , w6 = sb.lgl(k)


##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

u7 = triangle(x7)
u7_m = modal_frequency_reduction(u7, x7, w7)
##############################################




fig, ax = plt.subplots(figsize=(10,5))
ax.plot(x7,np.zeros_like(x7), "o",label="$x_7$")
ax.plot(x6,np.zeros_like(x6), "x",label="$x_6$")
ax.plot(x7,u7,label="P7 Solution")
#ax.plot(x6,u6,label="P6 Solution - Naive")
#ax.plot(x6,u6_t,label="P6 Solution - Minimum L2")
#ax.plot(x7,u7_6t2, label="P7 from P6 (Naive-Approach)")
ax.plot(x7,u7_m,"x",label="P7 from Modal Reduction")
ax.legend()
ax.grid()
ax.set_title("Projecting P7 Jump onto a P6 Solution")
plt.show()

# %%
#######
# Testing the Sensor with Both Approaches on the Step-Jump
#######

##############################################################
###################### Functions #############################

# This function is for converting from nodal to modal represntation of the solution vecotr
def nodal_to_modal(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    return a

# This function takes in a lower order solution and kills the highest frequency 
def modal_frequency_reduction(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    
    # 4) Killing the highest frequency term
    a[-1] = 0
    
    # 5) Return Modal to Nodal 
    a = V.dot(a)
    return a

# This function calculates the energy of the highest mode in a modal representation of a solution
def fractional_energy_highest_mode(a):
    """
    Compute the fraction of total L²‐energy contained in the highest Legendre mode.
    
    Parameters
    ----------
    a : array_like, shape (n+1,)
        Modal coefficients [a₀, a₁, …, aₙ] of a polynomial of degree n.
    
    Returns
    -------
    float
        Fractional energy in mode n:
          Eₙ / Σ_{i=0}ⁿ Eᵢ,
        where Eᵢ = aᵢ²·(2/(2i+1)).
    """
    a = np.asarray(a)
    n = a.size - 1
    i = np.arange(a.size)
    # energy in each mode: E[i] = a[i]**2 * (2/(2*i+1))
    E = a**2 / (2/(2*i + 1))
    return E[n] / E.sum()


###################### Functions #############################
##############################################################


##############################################################
################ Beggining of Program ########################

E   = np.zeros(11)
E_n = np.zeros(11)
E_m = np.zeros(11)
for i in range(10):
    n = i+2 
    k = i+1
    x7 , w7 = sb.lgl(n)
    x6 , w6 = sb.lgl(k)


##############################################
#G = np.array([sb.lagrange(n,x7[i]) for i in range(n+1)])
    L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 

    u7 = np.where(x7 < 0, 0.0, 1.0)

#################################
# Interpolation onto a lower solution order 
    P6 = np.linalg.inv(sb.sbp_p(k))
    P7 = sb.sbp_p(n)

    u_lower = P6@(L6.T.dot(P7@u7))
# Interpolation back to original solution degree
    u7_n = L6.dot(u_lower)
#################################


#################################
# Projection to the modal space and killing the highest frequency
    u7_m = nodal_to_modal(u7,x7,w7)
    u7_m[-1] = 0
    u7_kill = modal_frequency_reduction(u7_m,x7,w7)
#################################

#################################
## Calcating the energy of the Solution 

# Projecting the Nodal solution onto the modal space 
    u7_nm = nodal_to_modal(u7_n,x7,w7)
# Calculating the fractional energy of the nodal approach
    E_n[i]   = fractional_energy_highest_mode(u7_nm)

# Calculating the fractional energy of the modal approach 
    E_m[i]   = fractional_energy_highest_mode(u7_m)

# Calculating the fractional energy of the un-modified jump
    u7_um    = nodal_to_modal(u7,x7,w7)
    E[i]     = fractional_energy_highest_mode(u7_um)
    
    
    #######################################################
    # Comparing the Scaling of the Sensor - From Persson 
    
    diff_n = u7_um-u7_nm
    diff_m = u7_um-u7_m
    S_n = (n**2)*diff_n.T.dot(P7@diff_n)/(u7_um.T.dot(P7@u7_um))
    S_m = (n**2)*diff_m.T.dot(P7@diff_m)/(u7_um.T.dot(P7@u7_um))
    
    
    #######################################################
    
    print("============================================================")
    print(f"Finished Calculating the Fractional Energy of {i+1}th Mode")
    print(f"Persson Sensor using the Nodal Interpolation Approach S_n = {S_n}")
    print(f"Persson Sensor using the Modal Projection Approach    S_m = {S_m}")
    print(f"Nodal Energy Approach = {E_n[i]}")
    print(f"Modal Energy Approach = {E_m[i]}")
    print(f"Energy of the unmodified jump = {E[i]}")
    print("============================================================")
# Out:
# ============================================================
# Finished Calculating the Fractional Energy of 1th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.906976744186047
# Persson Sensor using the Modal Projection Approach    S_m = 1.1627906976744184
# Nodal Energy Approach = 1.238097821391795e-31
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.7062146892655367
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 2th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.1574897499300123
# Persson Sensor using the Modal Projection Approach    S_m = 1.1574897499300123
# Nodal Energy Approach = 0.0
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.6218014174925535
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 3th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.3563531516729954
# Persson Sensor using the Modal Projection Approach    S_m = 1.1609193867151277
# Nodal Energy Approach = 0.0
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.5117000010948335
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 4th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.2228091607637614
# Persson Sensor using the Modal Projection Approach    S_m = 1.2228091607637674
# Nodal Energy Approach = 5.263505543352161e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.4583061452654468
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 5th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.3289526899545487
# Persson Sensor using the Modal Projection Approach    S_m = 1.2290146043741224
# Nodal Energy Approach = 1.821284710132349e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.39886942464677455
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 6th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.2700447350049453
# Persson Sensor using the Modal Projection Approach    S_m = 1.2700447350049375
# Nodal Energy Approach = 5.606380199206116e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.36362795922111063
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 7th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.336902762398671
# Persson Sensor using the Modal Projection Approach    S_m = 1.2753921849648373
# Nodal Energy Approach = 1.663662580509061e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.32636722586344985
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 8th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.3030675975782107
# Persson Sensor using the Modal Projection Approach    S_m = 1.3030675975782107
# Nodal Energy Approach = 0.0
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.3016063835969318
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 9th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.3490281300040041
# Persson Sensor using the Modal Projection Approach    S_m = 1.3072186769436949
# Nodal Energy Approach = 2.6502823533692927e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.2760309886427124
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 10th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 1.3268374169389527
# Persson Sensor using the Modal Projection Approach    S_m = 1.326837416938946
# Nodal Energy Approach = 2.2986714198542576e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.25774614765874626
# ============================================================

# %%
#######
# Testing the Sensor with Both Approaches on the Triangular Wave
#######

##############################################################
###################### Functions #############################

# This function is for converting from nodal to modal represntation of the solution vecotr
def nodal_to_modal(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    return a

# This function takes in a lower order solution and kills the highest frequency 
def modal_frequency_reduction(u, x, w):
    """
    Convert nodal values u at points x with weights w
    into modal Legendre coefficients a.
    
    u : array_like, shape (n+1,)   — nodal values
    x : array_like, shape (n+1,)   — LGL nodes
    w : array_like, shape (n+1,)   — corresponding LGL weights
    
    returns
    a : ndarray, shape (n+1,)      — modal Legendre coefficients
    """
    n = len(u) - 1
    
    # 1) Build Legendre‐Vandermonde: V[j,i] = P_i(x[j]) for i=0..n
    V = legvander(x, n)           # shape = (n+1, n+1)
    
    # 2) Compute weighted inner‐products β_i = Σ_j w[j]*P_i(x[j])*u[j]
    beta = V.T.dot(w * u)         # shape = (n+1,)
    
    # 3) Scale by (2i+1)/2 to get a_i
    i = np.arange(n+1)
    a = beta * (2*i + 1) / 2      # shape = (n+1,)
    
    # 4) Killing the highest frequency term
    a[-1] = 0
    
    # 5) Return Modal to Nodal 
    a = V.dot(a)
    return a

# This function calculates the energy of the highest mode in a modal representation of a solution
def fractional_energy_highest_mode(a):
    """
    Compute the fraction of total L²‐energy contained in the highest Legendre mode.
    
    Parameters
    ----------
    a : array_like, shape (n+1,)
        Modal coefficients [a₀, a₁, …, aₙ] of a polynomial of degree n.
    
    Returns
    -------
    float
        Fractional energy in mode n:
          Eₙ / Σ_{i=0}ⁿ Eᵢ,
        where Eᵢ = aᵢ²·(2/(2i+1)).
    """
    a = np.asarray(a)
    n = a.size - 1
    i = np.arange(a.size)
    # energy in each mode: E[i] = a[i]**2 * (2/(2*i+1))
    E = a**2 / (2/(2*i + 1))
    return E[-1] / E.sum()

###################### Functions #############################
##############################################################


##############################################################
################ Beggining of Program ########################

E   = np.zeros(11)
E_n = np.zeros(11)
E_m = np.zeros(11)
S_n_vec = []
S_m_vec = []
dim = []
fig, ax = plt.subplots(figsize=(10,6))
for i in range(10):
    n = i+2 
    k = i+1
    x7 , w7 = sb.lgl(n)
    x6 , w6 = sb.lgl(k)

    u7 = triangle(x7)
##############################################
# Projection to the modal space and killing the highest frequency
    u7_m = nodal_to_modal(u7,x7,w7) 
    


    if k > 2 and k % 2 == 0: 
        L6 = np.array([sb.lagrange(k-1,x7[i]) for i in range(n+1)])
        P6 = np.linalg.inv(sb.sbp_p(k-1))
        u7_m[-1] = 0
        u7_m[-2] = 0    
    else: 
        L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 
        P6 = np.linalg.inv(sb.sbp_p(k))
        u7_m[-1] = 0
    #L6 = np.array([sb.lagrange(k,x7[i]) for i in range(n+1)]) # Using the 
    #P6 = np.linalg.inv(sb.sbp_p(k))
    

#################################
# Interpolation onto a lower solution order 
    P7 = sb.sbp_p(n)

    u_lower = P6@(L6.T.dot(P7@u7))
# Interpolation back to original solution degree
    u7_n = L6.dot(u_lower)
#################################


#################################

#################################

#################################
## Calcating the energy of the Solution 

# Projecting the Nodal solution onto the modal space 
    u7_nm = nodal_to_modal(u7_n,x7,w7)
# Calculating the fractional energy of the nodal approach
    E_n[i]   = fractional_energy_highest_mode(u7_nm)

# Calculating the fractional energy of the modal approach 
    E_m[i]   = fractional_energy_highest_mode(u7_m)

# Calculating the fractional energy of the un-modified jump
    u7_um    = nodal_to_modal(u7,x7,w7)
    E[i]     = fractional_energy_highest_mode(u7_um)
    
    
    #######################################################
    # Comparing the Scaling of the Sensor - From Persson 
    
    diff_n = u7_um-u7_nm
    diff_m = u7_um-u7_m
    S_n = (n**3)*diff_n.T.dot(P7@diff_n)/(u7_um.T.dot(P7@u7_um))
    S_m = (n**3)*diff_m.T.dot(P7@diff_m)/(u7_um.T.dot(P7@u7_um))
    S_n_vec.append(S_n)
    S_m_vec.append(S_m)
    dim.append(n)
    
    #ax.legend()
    

    #######################################################
    
    
    print("============================================================")
    print(f"Finished Calculating the Fractional Energy of {i+1}th Mode")
    print(f"Persson Sensor using the Nodal Interpolation Approach S_n = {S_n}")
    print(f"Persson Sensor using the Modal Projection Approach    S_m = {S_m}")
    print(f"Nodal Energy Approach = {E_n[i]}")
    print(f"Modal Energy Approach = {E_m[i]}")
    print(f"Energy of the unmodified jump = {E[i]}")
    print("============================================================")


ax.plot(dim , S_n_vec,"--x", label="Sensor using nodal interpolation")
ax.plot(dim , S_m_vec,"--o",  label="Sensor using modal projection")    
ax.set_ylim(0, 12)
ax.set_xlim(1, 10)
ax.grid()
ax.set_title("Plot of the Sensor usin g the nodal interpolation and the modal projection")
plt.show()
# Out:
# ============================================================
# Finished Calculating the Fractional Energy of 1th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 6.8965517241379315
# Persson Sensor using the Modal Projection Approach    S_m = 6.8965517241379315
# Nodal Energy Approach = 0.0
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.9689922480620154
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 2th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 8.099999999999987
# Persson Sensor using the Modal Projection Approach    S_m = 2.0012293565742826e-31
# Nodal Energy Approach = 1.5565117217799965e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 5.188372405933327e-32
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 3th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 3.1567356557110493
# Persson Sensor using the Modal Projection Approach    S_m = 3.156735655711052
# Nodal Energy Approach = 1.0052564666382897e-31
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.3923061885992318
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 4th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 2.1055807051047806
# Persson Sensor using the Modal Projection Approach    S_m = 2.105580705104931
# Nodal Energy Approach = 4.791056838448502e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 1.148380113126581e-30
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 5th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 2.67031504135031
# Persson Sensor using the Modal Projection Approach    S_m = 2.670315041350303
# Nodal Energy Approach = 5.184021618750809e-31
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.2041430711661434
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 6th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 0.8303859119729251
# Persson Sensor using the Modal Projection Approach    S_m = 0.8303859119729924
# Nodal Energy Approach = 2.5697592832610158e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 7.071821319373628e-30
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 7th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 2.5216816138001206
# Persson Sensor using the Modal Projection Approach    S_m = 2.5216816138002116
# Nodal Energy Approach = 4.62743048624047e-29
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.12446935728342207
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 8th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 0.4604434888077677
# Persson Sensor using the Modal Projection Approach    S_m = 0.4604434888078873
# Nodal Energy Approach = 7.848563864505365e-30
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 8.476947446573692e-30
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 9th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 2.458749673332568
# Persson Sensor using the Modal Projection Approach    S_m = 2.458749673333206
# Nodal Energy Approach = 1.5368961316453518e-27
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 0.08369986340195082
# ============================================================
# ============================================================
# Finished Calculating the Fractional Energy of 10th Mode
# Persson Sensor using the Nodal Interpolation Approach S_n = 0.297223849687381
# Persson Sensor using the Modal Projection Approach    S_m = 0.2972238496892713
# Nodal Energy Approach = 1.3234372079589151e-28
# Modal Energy Approach = 0.0
# Energy of the unmodified jump = 1.4338952700112536e-28
# ============================================================
